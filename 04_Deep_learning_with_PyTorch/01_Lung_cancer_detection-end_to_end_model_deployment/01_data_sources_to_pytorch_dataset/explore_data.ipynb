# %% [markdown]
# # Combining data sources into a unified dataset
#
# - Loading and processing raw data files
# - Implementing a Python class to represent our data
# - Converting our data into a format usable by PyTorch
# - Visualizing the training and validation data
#
# Our goal is to be able to produce a training sample given our inputs of raw CT scan data and a list of annotations for those CTs.
#
# Our CT data comes in two files: a .mhd file containing metadata header information, and a .raw file containing the raw bytes that make up the 3D array. Each file’s name starts with a unique identifier called the series UID (the name comes from the Digital Imaging and Communications in Medicine [DICOM] nomenclature) for the CT scan in question. For example, for series UID 1.2.3, there would be two files: 1.2.3.mhd and 1.2.3.raw.
#
# Our Ct class will consume those two files and produce the 3D array, as well as the transformation matrix to convert from the patient coordinate system (which we will discuss in more detail in section 10.6) to the index, row, column coordinates needed by the array (these coordinates are shown as (I,R,C) in the figures and are denoted with _irc variable suffixes in the code).
#
# We will also load the annotation data provided by LUNA, which will give us a list of nodule coordinates, each with a malignancy flag, along with the series UID of the relevant CT scan. By combining the nodule coordinate with coordinate system transformation information, we get the index, row, and column of the voxel at the center of our nodule.
#
# Using the (I,R,C) coordinates, we can crop a small 3D slice of our CT data to use as the input to our model. Along with this 3D sample array, we must construct the rest of our training sample tuple, which will have the sample array, nodule status flag, series UID, and the index of this sample in the CT list of nodule candidates. This sample tuple is exactly what PyTorch expects from our Dataset subclass and represents the last section of our bridge from our original raw data to the standard structure of PyTorch tensors.
#
#
# Details of the ETL (dset.py) are indicated in the book Deep Learning with Pytorch (Eli Stevens, Luca Antiga, Thomas Viehmann).

# %%
# %matplotlib inline
import numpy as np

# %%
from p2ch10.dsets import getCandidateInfoList, getCt, LunaDataset
candidateInfo_list = getCandidateInfoList(requireOnDisk_bool=False)
positiveInfo_list = [x for x in candidateInfo_list if x[0]]
diameter_list = [x[1] for x in positiveInfo_list]

# %% [markdown]
# Get the total of positive nodules (actual cancer) from source data

# %%
print(len(positiveInfo_list))
print(positiveInfo_list[0])
# Out:
# 1557
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(66.58022805, 82.56931698, -110.5421104))

# %% [markdown]
# We have a few very large candidates, starting at 32 mm, but they rapidly drop off to half that size. The bulk of the candidates are in the 4 to 10 mm range, and several hundred don’t have size information at all. This looks as expected; you might recall that we had more actual nodules than we had diameter annotations.

# %%
for i in range(0, len(diameter_list), 100):
    print('{:4}  {:4.1f} mm'.format(i, diameter_list[i]))
# Out:
#    0  32.3 mm
#  100  18.5 mm
#  200  13.7 mm
#  300  10.7 mm
#  400   8.7 mm
#  500   7.6 mm
#  600   6.7 mm
#  700   6.1 mm
#  800   5.6 mm
#  900   5.1 mm
# 1000   4.7 mm
# 1100   4.3 mm
# 1200   0.0 mm
# 1300   0.0 mm
# 1400   0.0 mm
# 1500   0.0 mm

# %% [markdown]
# nodule information:

# %%
for candidateInfo_tup in positiveInfo_list[:10]:
    print(candidateInfo_tup)
for candidateInfo_tup in positiveInfo_list[-10:]:
    print(candidateInfo_tup)
    
for candidateInfo_tup in positiveInfo_list:
    if candidateInfo_tup.series_uid.endswith('565'):
        print(candidateInfo_tup)
# Out:
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=32.27003025, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.287966244644280690737019247886', center_xyz=(66.58022805, 82.56931698, -110.5421104))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(48.23675256, 37.47721004, -98.64208784))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(44.19, 37.79, -107.01))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=30.61040636, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112740418331256326754121315800', center_xyz=(40.69, 32.19, -97.15))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=27.44242293, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.943403138251347598519939390311', center_xyz=(-45.29440163, 74.86925386, -97.52812481))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=27.07544345, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.481278873893653517789960724156', center_xyz=(-103.065604, -5.083279383, -204.3916706))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=26.83708074, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754493433372433148666', center_xyz=(121.1529094, 12.91360033, -159.3994972))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=26.83708074, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754493433372433148666', center_xyz=(118.7419704, 11.75601399, -165.0221229))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=26.83708074, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.487268565754493433372433148666', center_xyz=(112.706253, 8.25, -159.0))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=25.87269662, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.177086402277715068525592995222', center_xyz=(-65.18, 53.2, -105.48))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(94.813959, 192.0586641, -518.0))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(90.818736, 204.227383, -513.455))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(89.32, 190.84, -516.82))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(89.32, 143.23, -427.1))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(88.690908, 156.4336401, -428.0))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(88.690908, 150.3105891, -434.0))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(84.4005695, 150.2070126, -425.35))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(8.8, 174.74, -401.87))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(5.99, 171.94, -398.37))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(1.79, 166.34, -408.88))
# CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.378436317, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565', center_xyz=(146.239444, -161.190112, -310.777295))

# %% [markdown]
# histogram of nodule's diameter:

# %%
np.histogram(diameter_list)
# Out:
# (array([384, 550, 281, 117,  78,  59,  42,  34,   8,   4]),
#  array([ 0.        ,  3.22700302,  6.45400605,  9.68100907, 12.9080121 ,
#         16.13501512, 19.36201815, 22.58902117, 25.8160242 , 29.04302722,
#         32.27003025]))

# %%
from p2ch10.vis import findPositiveSamples, showCandidate
positiveSample_list = findPositiveSamples()
# Out:
# 2025-09-19 01:30:50,759 INFO     pid:72685 p2ch10.dsets:182:__init__ <p2ch10.dsets.LunaDataset object at 0x7603f2024150>: 754975 training samples
# 0 CandidateInfoTuple(isNodule_bool=True, diameter_mm=15.13080337, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.897684031374557757145405000951', center_xyz=(-104.2535243, 142.7860645, -709.618551))
# 1 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.477744916, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.215640837032688688030770057224', center_xyz=(95.75543943, -23.23279864, -107.8593292))
# 2 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.163901773171373940247829492387', center_xyz=(-56.59, 33.44, -420.08))
# 3 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.206700455, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.282779922503707013097174625409', center_xyz=(82.64467593, -82.26416667, -162.6957639))
# 4 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.41336635, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.328944769569002417592093467626', center_xyz=(-91.7884345, -5.7590625, -138.8975))
# 5 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.104624209, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.112767175295249119452142211437', center_xyz=(99.3169244, 23.8900418, -138.0981331))
# 6 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.719422603, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188059920088313909273628445208', center_xyz=(-49.69, 92.385, 1478.995))
# 7 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.52433762, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.226456162308124493341905600418', center_xyz=(91.03180348, 33.87648772, -150.2530523))
# 8 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.23154253, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.463214953282361219537913355115', center_xyz=(89.6725287, 72.89418536, -236.1880978))
# 9 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.45617819, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.147250707071097813243473865421', center_xyz=(85.04297201, 41.26162663, -39.45221221))
# 10 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.304621719, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188059920088313909273628445208', center_xyz=(-110.420925, 84.62595, 1507.02))
# 11 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.217909816, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.392861216720727557882279374324', center_xyz=(-37.24708969, -33.15106186, -61.31671159))
# 12 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187451715205085403623595258748', center_xyz=(94.86824942, -22.41525826, -208.0309825))
# 13 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.983856442, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.215640837032688688030770057224', center_xyz=(63.68297275, -77.751065, -143.4625028))
# 14 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.146987333806092287055399155268', center_xyz=(84.75031405, -16.86522889, -253.3138758))
# 15 CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.832603383, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.337005960787660957389988207064', center_xyz=(-76.115, -74.865, -144.32))
# 16 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.80179732, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.299767339686526858593516834230', center_xyz=(-58.2407749, 73.74015774, -147.1509642))
# 17 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.800248866, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.129055977637338639741695800950', center_xyz=(-95.6429863, -88.21797221, 1130.845588))
# 18 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.60251126, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.235364978775280910367690540811', center_xyz=(64.33249613, 30.09225656, -237.0078411))
# 19 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.06629748, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.309901913847714156367981722205', center_xyz=(-45.9259759, 14.7670469, -198.6425487))
# 20 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.283782817, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.534006575256943390479252771547', center_xyz=(124.4601424, -8.416102, -208.8481248))
# 21 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.611381537, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.195557219224169985110295082004', center_xyz=(-64.8134375, -2.17125, -155.12))
# 22 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.858527982, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.246225645401227472829175288633', center_xyz=(85.35507707, 68.33253169, 1553.089264))
# 23 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.430802339, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.868211851413924881662621747734', center_xyz=(-23.179375, 78.0565625, -137.0375))
# 24 CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.813182598, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.169128136262002764211589185953', center_xyz=(-27.59, 29.72, -74.48))
# 25 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.982909574, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.293593766328917170359373773080', center_xyz=(-62.51966996, 55.56040767, -96.01004261))
# 26 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.235946908, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.173101104804533997398137418032', center_xyz=(116.6301555, 28.53453125, -121.885))
# 27 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.696771445, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.215640837032688688030770057224', center_xyz=(78.81523575, 43.96092525, -86.38750275))
# 28 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.765930210026773090100532964804', center_xyz=(-68.927797, 204.982297, -678.799988))
# 29 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.72670328, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.259227883564429312164962953756', center_xyz=(-29.89697148, 47.50075358, -84.95375479))
# 30 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.805890569, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.300146276266881736689307479986', center_xyz=(-68.7, -157.29, -175.575))
# 31 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.334194889, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.119209873306155771318545953948', center_xyz=(-68.925, -83.88, -161.07))
# 32 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.670798042, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.908250781706513856628130123235', center_xyz=(-62.13312575, 91.9932805, -213.315))
# 33 CandidateInfoTuple(isNodule_bool=True, diameter_mm=9.002203924, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.212346425055214308006918165305', center_xyz=(69.25982174, 70.99963248, -222.835221))
# 34 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.270390050141765094612147226290', center_xyz=(-54.555, -21.905, -152.965))
# 35 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187694838527128312070807533473', center_xyz=(89.3359375, -234.7109375, -206.5))
# 36 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.140896043, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.107351566259572521472765997306', center_xyz=(82.51416393, -82.73716979, -178.8649685))
# 37 CandidateInfoTuple(isNodule_bool=True, diameter_mm=18.79314938, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.143622857676008763729469324839', center_xyz=(-75.97493923, -150.22287, -128.6177086))
# 38 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.918815315, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.603126300703296693942875967838', center_xyz=(66.555, 108.62, -168.5))
# 39 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.404768898286087278137462774930', center_xyz=(88.95509599, 224.25074, -586.9018645))
# 40 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.368487089, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.868211851413924881662621747734', center_xyz=(-80.31, 82.42, -168.865))
# 41 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.251282657, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.292057261351416339496913597985', center_xyz=(-92.63809136, -208.706634, -203.0733772))
# 42 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.898838135, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972', center_xyz=(113.2506545, 65.18909608, -244.3071852))
# 43 CandidateInfoTuple(isNodule_bool=True, diameter_mm=24.77327957, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.146987333806092287055399155268', center_xyz=(96.72401845, -15.39248521, -254.0883677))
# 44 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.143622857676008763729469324839', center_xyz=(-77.06897397, -143.671014, -127.17))
# 45 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.249314567767437206995861966896', center_xyz=(30.62, 73.46, -273.83))
# 46 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.945821582, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.312704771348460502013249647868', center_xyz=(20.65089525, 147.8230968, -124.305))
# 47 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.131939324905446238286154504249', center_xyz=(-96.47, 85.17, 1454.23))
# 48 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.329404588567903628160652715124', center_xyz=(37.13, -20.47, -85.58))
# 49 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.090964239, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.534083630500464995109143618896', center_xyz=(-42.775, -3.325, -114.8))
# 50 CandidateInfoTuple(isNodule_bool=True, diameter_mm=13.55294288, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.290135156874098366424871975734', center_xyz=(-66.41149823, 69.37938404, -280.628726))
# 51 CandidateInfoTuple(isNodule_bool=True, diameter_mm=12.55350151, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.614147706162329660656328811671', center_xyz=(-44.43916203, 61.19743974, -175.5965779))
# 52 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.318099839, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.162351539386551708034407968929', center_xyz=(116.2095789, -173.8576232, -162.5125))
# 53 CandidateInfoTuple(isNodule_bool=True, diameter_mm=10.16765351, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.603126300703296693942875967838', center_xyz=(-31.83756652, 27.45344529, -169.5319243))
# 54 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.744966449, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.179162671133894061547290922949', center_xyz=(-127.8077778, 110.9965098, -740.649994))
# 55 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.716992744, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.141430002307216644912805017227', center_xyz=(-148.0185485, -165.6679815, -289.127085))
# 56 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.133374031, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.129007566048223160327836686225', center_xyz=(44.56361554, 99.9665658, -139.4239944))
# 57 CandidateInfoTuple(isNodule_bool=True, diameter_mm=16.92306528, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.481278873893653517789960724156', center_xyz=(33.13173965, 36.26191399, -176.9639851))
# 58 CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.887997704, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.193964947698259739624715468431', center_xyz=(16.20995925, 67.1280905, -31.22250325))
# 59 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.958169738, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.259543921154154401875872845498', center_xyz=(-55.6865625, -33.976093, -144.4462505))
# 60 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.073945715, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.187966156856911682643615997798', center_xyz=(69.76479625, -37.41042025, -146.427503))
# 61 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.850739282072340578344345230132', center_xyz=(-50.76, -40.46, -136.56))
# 62 CandidateInfoTuple(isNodule_bool=True, diameter_mm=15.27003429, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.243094273518213382155770295147', center_xyz=(36.10320141, 57.09032202, -225.0180488))
# 63 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.190273745, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.111496024928645603833332252962', center_xyz=(100.344641, 28.856482, -212.9))
# 64 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.62818632, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.305887072264491016857673607285', center_xyz=(-128.6982805, -1.435939, -213.5175005))
# 65 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.206097113343059612247503064658', center_xyz=(72.74, -130.15, -152.19))
# 66 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.264828408, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.332829333783605240302521201463', center_xyz=(-13.670443, 100.3802505, -125.3125))
# 67 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.300136985030081433029390459071', center_xyz=(113.36, 1.99, -229.42))
# 68 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.100621383016233746780170740405', center_xyz=(88.690908, 150.3105891, -434.0))
# 69 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.300270516469599170290456821227', center_xyz=(-111.115, -147.08, -281.48))
# 70 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.838097863, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.332829333783605240302521201463', center_xyz=(-88.6693825, 19.0701005, -176.32))
# 71 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.851190527, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.148229375703208214308676934766', center_xyz=(74.13411993, -152.7247918, -178.9290825))
# 72 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.196392768, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972', center_xyz=(-147.113574, -15.759632, -241.03))
# 73 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.502295592, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.191266041369462391833537519639', center_xyz=(-96.50900032, -97.02562441, -325.0286375))
# 74 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.815802572, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.249404938669582150398726875826', center_xyz=(61.77623197, 65.88656411, -282.1583353))
# 75 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.663019255629770796363333877035', center_xyz=(-42.0921965, 113.7752293, -554.780012))
# 76 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.586830375, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.225227615446398900698431118292', center_xyz=(97.87271025, 59.32622, -182.3150025))
# 77 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.360638607, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.114914167428485563471327801935', center_xyz=(-34.1029155, -9.53744, -37.6650075))
# 78 CandidateInfoTuple(isNodule_bool=True, diameter_mm=11.88422357, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.826829446346820089862659555750', center_xyz=(23.25308124, 77.7075896, -241.8866585))
# 79 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.961023634, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.122914038048856168343065566972', center_xyz=(-144.0308775, 76.77438328, -260.5128631))
# 80 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.3033558, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.142154819868944114554521645782', center_xyz=(36.72347525, -155.9695643, 959.096122))
# 81 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.006388591, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.238019241099704094018548301753', center_xyz=(-58.42734375, -55.56171875, -196.2225003))
# 82 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.277202539, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.997611074084993415992563148335', center_xyz=(42.89512201, 74.25103695, -200.6259776))
# 83 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.920275846, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.478062284228419671253422844986', center_xyz=(-54.7, 80.83, -175.97))
# 84 CandidateInfoTuple(isNodule_bool=True, diameter_mm=23.93362973, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.267957701183569638795986183786', center_xyz=(-93.46692606, -175.3617914, 213.7387065))
# 85 CandidateInfoTuple(isNodule_bool=True, diameter_mm=18.98004463, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.948414623428298219623354433437', center_xyz=(-82.17468553, 22.5299682, -184.1271642))
# 86 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.736403192, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.332829333783605240302521201463', center_xyz=(-37.92220225, -29.93317861, -111.2947909))
# 87 CandidateInfoTuple(isNodule_bool=True, diameter_mm=5.839687338, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.692598144815688523679745963696', center_xyz=(-35.5616203, 6.913160691, -86.52640767))
# 88 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.300136985030081433029390459071', center_xyz=(113.36, 16.7, -226.59))
# 89 CandidateInfoTuple(isNodule_bool=True, diameter_mm=4.481934217, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.309955999522338651429118207446', center_xyz=(87.6634375, -10.56171875, -73.73000125))
# 90 CandidateInfoTuple(isNodule_bool=True, diameter_mm=8.70905255, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.188265424231150847356515802868', center_xyz=(-60.53510804, 70.60977389, -58.61649777))
# 91 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.882070241245008756731854510592', center_xyz=(88.895123, 31.874848, -48.809998))
# 92 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.232717756, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.240969450540588211676803094518', center_xyz=(-67.09401524, 66.9188239, -200.5371728))
# 93 CandidateInfoTuple(isNodule_bool=True, diameter_mm=7.6317087, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.114218724025049818743426522343', center_xyz=(75.4115655, 7.77625, -195.567495))
# 94 CandidateInfoTuple(isNodule_bool=True, diameter_mm=6.436398619, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219428004988664846407984058588', center_xyz=(127.500782, 44.780468, -189.175))
# 95 CandidateInfoTuple(isNodule_bool=True, diameter_mm=14.19833109, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.121993590721161347818774929286', center_xyz=(-94.66968055, 60.58037099, -261.0028654))
# 96 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.219618492426142913407827034169', center_xyz=(-94.79, -92.27, -137.7))
# 97 CandidateInfoTuple(isNodule_bool=True, diameter_mm=0.0, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.292057261351416339496913597985', center_xyz=(78.802828, -169.150316, -149.20136))
# 98 CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.93841182, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.216882370221919561230873289517', center_xyz=(-89.43931272, -5.031199392, -81.83162655))
# 99 CandidateInfoTuple(isNodule_bool=True, diameter_mm=3.423341719, series_uid='1.3.6.1.4.1.14519.5.2.1.6279.6001.176638348958425792989125209419', center_xyz=(96.9, 41.5, -79.97))

# %%
series_uid = positiveSample_list[11][2]
showCandidate(series_uid)
# Out:
# 2025-09-19 01:30:57,360 INFO     pid:72685 p2ch10.dsets:182:__init__ <p2ch10.dsets.LunaDataset object at 0x7603dc402b90>: 853 training samples
# <div id='3c5cfb4e-bc46-46bd-9541-cb79a6e013ef'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.392861216720727557882279374324 475 False [475]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565'
showCandidate(series_uid)
# Out:
# 2025-09-19 01:31:03,366 INFO     pid:72685 p2ch10.dsets:182:__init__ <p2ch10.dsets.LunaDataset object at 0x7603e633e8d0>: 1333 training samples
# <div id='d38d5e52-2bce-4554-892b-31fbd70b523a'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.124154461048929153767743874565 774 False [774]

# %%
series_uid = '1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354'
showCandidate(series_uid)
# Out:
# 2025-09-19 01:31:09,453 INFO     pid:72685 p2ch10.dsets:182:__init__ <p2ch10.dsets.LunaDataset object at 0x7603eac4e8d0>: 1129 training samples
# <div id='313058de-332d-430b-ab83-1f5f8630d146'></div>
# 1.3.6.1.4.1.14519.5.2.1.6279.6001.126264578931778258890371755354 951 False [951]

# %% [markdown]
# Converting our data into a format usable by PyTorch:

# %%
LunaDataset()[0]
# Out:
# 2025-09-19 01:31:14,609 INFO     pid:72685 p2ch10.dsets:182:__init__ <p2ch10.dsets.LunaDataset object at 0x7603dec8db10>: 754975 training samples
# (tensor([[[[-884., -898., -902.,  ..., -160., -180., -190.],
#            [-930., -914., -918.,  ..., -156., -166., -148.],
#            [-886., -886., -870.,  ..., -106., -122., -116.],
#            ...,
#            [-846., -844., -844.,  ...,   56.,   48.,   82.],
#            [-940., -932., -878.,  ...,  112.,   82.,   90.],
#            [-844., -880., -870.,  ...,   56.,   22.,   -6.]],
#
#           [[-826., -808., -822.,  ...,  -92., -122., -118.],
#            [-888., -862., -860.,  ...,  -94., -120., -110.],
#            [-888., -888., -856.,  ...,  -94., -110., -134.],
#            ...,
#            [-822., -844., -864.,  ...,   44.,   62.,   92.],
#            [-842., -870., -838.,  ...,   88.,   52.,   74.],
#            [-804., -848., -856.,  ...,   68.,   28.,   50.]],
#
#           [[-836., -830., -850.,  ...,    4.,   -2.,  -10.],
#            [-846., -860., -898.,  ...,  -22.,  -56.,  -50.],
#            [-826., -852., -854.,  ...,  -24.,  -40.,  -56.],
#            ...,
#            [-568., -648., -752.,  ...,   -6.,    8.,   36.],
#            [-686., -744., -800.,  ...,   14.,   -6.,   32.],
#            [-798., -786., -784.,  ...,   66.,   46.,   38.]],
#
#           ...,
#
#           [[-856., -882., -834.,  ..., -882., -864., -810.],
#            [-768., -798., -796.,  ..., -916., -888., -792.],
#            [-724., -726., -760.,  ..., -892., -906., -872.],
#            ...,
#            [-866., -790., -762.,  ..., -850., -844., -834.],
#            [-852., -756., -740.,  ..., -872., -870., -776.],
#            [-858., -826., -828.,  ..., -854., -814., -640.]],
#
#           [[-874., -882., -822.,  ..., -908., -852., -794.],
#            [-842., -874., -818.,  ..., -928., -900., -822.],
#            [-830., -840., -796.,  ..., -938., -918., -878.],
#            ...,
#            [-860., -864., -872.,  ..., -872., -858., -854.],
#            [-802., -816., -858.,  ..., -834., -828., -796.],
#            [-832., -812., -846.,  ..., -860., -774., -606.]],
#
#           [[-874., -870., -856.,  ..., -878., -830., -834.],
#            [-846., -874., -870.,  ..., -916., -880., -846.],
#            [-844., -860., -858.,  ..., -914., -886., -874.],
#            ...,
#            [-884., -912., -932.,  ..., -860., -802., -750.],
#            [-860., -894., -918.,  ..., -764., -768., -714.],
#            [-866., -884., -906.,  ..., -740., -618., -472.]]]]),
#  tensor([1, 0]),
#  '1.3.6.1.4.1.14519.5.2.1.6279.6001.300246184547502297539521283806',
#  tensor([ 76, 174, 184]))

# %% [markdown]
# Some visualizations:

# %%
import numpy as np
import ipyvolume as ipv
V = np.zeros((128,128,128)) # our 3d array
# outer box
V[30:-30,30:-30,30:-30] = 0.75
V[35:-35,35:-35,35:-35] = 0.0
# inner box
V[50:-50,50:-50,50:-50] = 0.25
V[55:-55,55:-55,55:-55] = 0.0
ipv.quickvolshow(V, level=[0.25, 0.75], opacity=0.03, level_width=0.1, data_min=0, data_max=1)
# Out:
# /opt/conda/lib/python3.11/site-packages/ipyvolume/serialize.py:102: RuntimeWarning: invalid value encountered in cast
#   subdata[..., i] = ((gradient[i][zindex] / 2.0 + 0.5) * 255).astype(np.uint8)
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, ste…

# %%
ct = getCt(series_uid)
ipv.quickvolshow(ct.hu_a, level=[0.25, 0.5, 0.9], opacity=0.1, level_width=0.1, data_min=-1000, data_max=1000)
# Out:
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.25, max=1.0, ste…

# %% [markdown]
# # Note: the following visualization doesn't look very good.
# It's only included here for completeness.

# %%
import scipy.ndimage.morphology
def build2dLungMask(ct, mask_ndx, threshold_gcc = 0.7):
    dense_mask = ct.hu_a[mask_ndx] > threshold_gcc
    denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
    tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
    body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
    air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)

    lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask


def build3dLungMask(ct):
    air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = mask_list = \
        [np.zeros_like(ct.hu_a, dtype=np.bool) for _ in range(6)]

    for mask_ndx in range(ct.hu_a.shape[0]):
        for i, mask_ary in enumerate(build2dLungMask(ct, mask_ndx)):
            mask_list[i][mask_ndx] = mask_ary

    return air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask

# %%
from p2ch10.dsets import getCt
ct = getCt(series_uid)
air_mask, lung_mask, dense_mask, denoise_mask, tissue_mask, body_mask = build3dLungMask(ct)
# Out:
# /tmp/ipykernel_72685/2460116618.py:4: DeprecationWarning: Please import `binary_closing` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   denoise_mask = scipy.ndimage.morphology.binary_closing(dense_mask, iterations=2)
# /tmp/ipykernel_72685/2460116618.py:5: DeprecationWarning: Please import `binary_opening` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   tissue_mask = scipy.ndimage.morphology.binary_opening(denoise_mask, iterations=10)
# /tmp/ipykernel_72685/2460116618.py:6: DeprecationWarning: Please import `binary_fill_holes` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   body_mask = scipy.ndimage.morphology.binary_fill_holes(tissue_mask)
# /tmp/ipykernel_72685/2460116618.py:7: DeprecationWarning: Please import `binary_fill_holes` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   air_mask = scipy.ndimage.morphology.binary_fill_holes(body_mask & ~tissue_mask)
# /tmp/ipykernel_72685/2460116618.py:9: DeprecationWarning: Please import `binary_dilation` from the `scipy.ndimage` namespace; the `scipy.ndimage.morphology` namespace is deprecated and will be removed in SciPy 2.0.0.
#   lung_mask = scipy.ndimage.morphology.binary_dilation(air_mask, iterations=2)

# %%
bones = ct.hu_a * (ct.hu_a > 1.5)
lungs = ct.hu_a * air_mask
ipv.figure()
ipv.pylab.volshow(bones + lungs, level=[0.17, 0.17, 0.23], data_min=100, data_max=900)
ipv.show()
# Out:
# Container(children=[VBox(children=(HBox(children=(Label(value='levels:'), FloatSlider(value=0.17, max=1.0, ste…
